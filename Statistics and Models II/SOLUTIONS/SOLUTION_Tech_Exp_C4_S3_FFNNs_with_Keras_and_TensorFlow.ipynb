# %% [markdown]
# # Technology Explorers Course 4, Session 3: FFNNs with Keras/TensorFlow
#
# **Instructor**: Wesley Beckner
#
# **Contact**: wesleybeckner@gmail.com
#
# <br>
#
# ---
#
# <br>
#
# In this session we will continue with our discussion on neural networks. Specifically, we will revisit the concept of learning curves, regularization and classification tasks, this time as they pertain to neural networks!
#
# _images in this notebook borrowed from [Ryan Holbrook](https://mathformachines.com/)_
#
# <br>
#
# ---
#
# <br>
#
# <a name='top'></a>
#
# # Contents
#
# * 2.0 [Preparing Environment and Importing Data](#x.0)
#   * 2.0.1 [Import Packages](#x.0.1)
#   * 2.0.2 [Load Dataset](#x.0.2)
# * 2.1 [Feature Engineering](#x.1)
# * 2.2 [Building the Model](#x.2)
#   * 2.2.1 [Layers, Nodes, and Activation Functions](#x.2.1)
# * 2.3 [Compiling the Model](#x.3)
#   * 2.3.1 [Loss, Optimizer, and Metrics](#x.3.1)
# * 2.4 [Fitting the Model](#x.4)
#   * 2.4.1 [Epoch, Batch](#x.4.1)
# * 2.5 [Evaluating the Model](#x.5)
# * 2.6 [Convolutional NNs](#x.6)
#   * 2.6.1 [Convolutional Layers](#x.6.1)
#   * 2.6.2 [Pooling Layers](#x.6.2)
#   * 2.6.3 [Flattening](#x.6.3)
#   * 2.6.4 [Dropout](#x.6.4)
#
#
#
# <br>
#
# ---

# %% [markdown]
# <a name='x.0'></a>
#
# ## 2.0 Preparing Environment and Importing Data
#
# [back to top](#top)

# %%
# !pip uninstall scikit-learn -y

# !pip install -U scikit-learn
# Out:
# Found existing installation: scikit-learn 0.24.2
# Uninstalling scikit-learn-0.24.2:
#   Successfully uninstalled scikit-learn-0.24.2
# Collecting scikit-learn
#   Using cached scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-0.24.2

# %% [markdown]
# <a name='x.0.1'></a>
#
# ### 2.0.1 Import Packages
#
# [back to top](#top)

# %%
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from copy import copy
import numpy as np
sns.set()

from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import set_config
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
set_config(display='diagram')

# %% [markdown]
# <a name='x.0.1'></a>
#
# ### 2.0.2 Load Dataset
#
# [back to top](#top)

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('quality')

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = np.log(y_train) # log output y
y_val_std = np.log(y_val) # log output y
y_test_std = np.log(y_test) # log output y

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f90d7c3c2d0>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f90d7c3c150>)])

# %% [markdown]
# <a name='x.1'></a>
#
# ## 2.1 Evaluating the Model
#
# [back to top](#top)
#
# In the last session, we randomly chose 10 and then 30 epochs (10 rounds of the training data) to train our neural network. Now we'll garner the language to be more systematic in our approach.

# %% [markdown]
# ### 2.1.1 Learning Curves
#
# Recall learning curves from last week, where we plot model score (accuracy/mse/r2/etc.) over model complexity (trees in a forest, degrees in a polynomial, etc.):
#
# <p align=center>
# <img src="https://jakevdp.github.io/PythonDataScienceHandbook/figures/05.03-validation-curve.png" width=500px></img>
#
#
# <small>[img src](https://jakevdp.github.io/PythonDataScienceHandbook/05.03-hyperparameters-and-model-validation.html)
#
# </p>
#
# We have a similar situation with neural networks, accept here, the model complexity is defined by both the number of epochs, and the capacity of the model.

# %% [markdown]
# #### 2.1.1.1 Training Data (Epochs)
#
# A greater number of epochs allows the model to further tune itself to the training data. Remember that our model solves its weights by a solver function, most often a form of stochastic gradient descent. Because this solver is iterative, the longer we allow it run the closer it will get to finding its true weights. The caveat here is that, like we have seen before, the model is only learning the proper weights according to the training data, which we know includes noise, otherwise known as irreducible error. Our data science senses should be tingling: there's an optimum number of epochs here, and it will counter balance the trade-off between error due to bias (too few epochs) and error due to variance (too many epochs).

# %% [markdown]
# #### 2.1.1.2 Complexity (Capacity)
#
#
#
# The capacity of the model is defined by the architecture. It is the total number of trainable weights available to the solver function. The more weights, the more capacity. Capacity determines the upper limit for which our model can learn relationships between the data. Again we should recall from our session on feature engineering: the more training data we have, the more capacity we should give our model to account for that abundance of training data. This is also influenced by the actual complexity between the input and output data, X and y, who's function we are attempting to approximate with the neural network. The more complicated the relationship, the more capacity we should give to our model.
#
# Capacity can be increased either by widening our model (increasing the neurons in a layer) or deepening our model(increasing the number of layers in our model).

# %% [markdown]
# ### 2.1.2 Early Stopping
#
# [back to top](#top)
#
# Without knowing the true relationship between X and y, or the degree to which there is irreducible error in our data, we return to our familiar learning curves to pragmaticaly determine how long we should train our model, that is, how many epochs should be ran and how many neurons we should give our model.
#
# When dealing with the number of epochs, we can program this into the training session automatically with early stopping. Early stopping allows us to discontinue training the model when either the validation score stops improving, or stops improving by some margin. This allows us to both save time during training and to avoid overfitting our model.
#
# To account for underfitting (not training the model long enough) we can simply set our number of training epochs to some large number and allow early stopping to take care of the rest.
#
# In TF/Keras, we can envoke early stopping by setting a **_callback_** a callback is simply a function that is called every so often.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# %% [markdown]
# In the above, we are saying detect when the validation loss stops improving by 0.001; check this over the past 20 epochs to avoid stopping early due to noise; and restore the best weights over that past 20 epoch period when early stopping is envoked. To envoke early stopping we would enlist it in our call to fit like so:
#
# ```
# model.fit(
#     # X, y, batch size etc, ...
#     callbacks=[early_stopping],
# )
# ```

# %% [markdown]
# ### 2.1.3 Exercise: Try Early Stopping
#
# Take your best model from the last exercise in session 1 and apply early stopping

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

model = keras.Sequential([
    ### YOUR CODE HERE ###
    layers.Dense(512, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.Dense(512, activation='relu'),
    layers.Dense(512, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 512)               7168
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 532,993
# Trainable params: 532,993
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 1s 35ms/step - loss: 0.6277 - val_loss: 0.2173
# Epoch 2/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.1516 - val_loss: 0.1129
# Epoch 3/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0833 - val_loss: 0.0617
# Epoch 4/1000
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0471 - val_loss: 0.0371
# Epoch 5/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0294 - val_loss: 0.0258
# Epoch 6/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0212 - val_loss: 0.0210
# Epoch 7/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0182 - val_loss: 0.0181
# Epoch 8/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0163 - val_loss: 0.0180
# Epoch 9/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0158 - val_loss: 0.0188
# Epoch 10/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0151 - val_loss: 0.0168
# Epoch 11/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0146 - val_loss: 0.0156
# Epoch 12/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0134 - val_loss: 0.0154
# Epoch 13/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0132 - val_loss: 0.0172
# Epoch 14/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0133 - val_loss: 0.0154
# Epoch 15/1000
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0125 - val_loss: 0.0151
# Epoch 16/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0129 - val_loss: 0.0157
# Epoch 17/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0129 - val_loss: 0.0164
# Epoch 18/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0121 - val_loss: 0.0151
# Epoch 19/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0122 - val_loss: 0.0158
# Epoch 20/1000
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0124 - val_loss: 0.0151
# Epoch 21/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0120 - val_loss: 0.0164
# Epoch 22/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0120 - val_loss: 0.0152
# Epoch 23/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0113 - val_loss: 0.0163
# Epoch 24/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0112 - val_loss: 0.0146
# Epoch 25/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0109 - val_loss: 0.0160
# Epoch 26/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0129 - val_loss: 0.0156
# Epoch 27/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0115 - val_loss: 0.0153
# Epoch 28/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0109 - val_loss: 0.0155
# Epoch 29/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0103 - val_loss: 0.0157
# Epoch 30/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0107 - val_loss: 0.0144
# Epoch 31/1000
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0098 - val_loss: 0.0141
# Epoch 32/1000
# 15/15 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0154
# Epoch 33/1000
# 15/15 [==============================] - 0s 24ms/step - loss: 0.0101 - val_loss: 0.0153
# Epoch 34/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0099 - val_loss: 0.0152
# Epoch 35/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0095 - val_loss: 0.0156
# Epoch 36/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0095 - val_loss: 0.0166
# Epoch 37/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0097 - val_loss: 0.0152
# Epoch 38/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0093 - val_loss: 0.0144
# Epoch 39/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0087 - val_loss: 0.0142
# Epoch 40/1000
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0086 - val_loss: 0.0158
# Epoch 41/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0089 - val_loss: 0.0165
# Epoch 42/1000
# 15/15 [==============================] - 0s 25ms/step - loss: 0.0083 - val_loss: 0.0147
# Epoch 43/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0086 - val_loss: 0.0146
# Epoch 44/1000
# 15/15 [==============================] - 0s 26ms/step - loss: 0.0084 - val_loss: 0.0150

# %%
# Show the learning curves
history_df = pd.DataFrame(history.history)
fig, ax = plt.subplots(1,1)
history_df.plot(ax=ax)
ax.set_ylim(0,.1)
# Out:
# (0.0, 0.1)

# %%
y_test_pred = (np.exp(model.predict(X_test_std)))
plt.plot(y_test_pred, np.exp(y_test_std), ls='', marker='o')
plt.xlim(4, 10)
# Out:
# (4.0, 10.0)

# %% [markdown]
# ## 2.2 Regularizing Layers: Dropout and Batch Normalization
#
# [back to top](#top)
#
# There are dozens of different layer types for accomplishing different tasks (and more are being generated by researchers all the time). While we're on the topic of general model performance, there are two layer types we'll want to introduce here: **_dropout_** and **_batch normalization_** or just batchnorm. What we'll see with both of these types is that while they don't contain any neurons, they're useful to think of as layers, because they are an extra processing step between neural layers.

# %% [markdown]
# ### 2.2.1 Dropout
#
# [back to top](#top)
#
# Dropout is the Neural Network response to the wide success of ensemble learning. In a dropout layer, random neurons are dropped in each batch of training, i.e. their weighted updates are not sent to the next neural layer. Just as with random forests, the end result is that the neural network can be thought of as many _independent models_ that _vote_ on the final output.
#
# Put another way, when a network does not contain dropout layers, and has a capacity that exceeds that which would be suited for the true, underlying complexity level of the data, it can begin to fit to noise. This ability to fit to noise is based on very specific relationships between neurons, which fire uniquely given the particular training example. Adding dropout _breaks_ these specific neural connections, and so the neural network as a whole is forced to find weights that apply generally, as there is no guarantee they will be _turned on_ when their specific training example they would usually overfit for comes around again.
#
# <p align=center>
# <img src="https://i.imgur.com/a86utxY.gif"></img>
# </p>
# <small> Network with 50% dropout </small>
#
# A last thing to note, is that after adding dropout, we will typically need to add additional layers to our network to maintain the overall capacity of the network.

# %%
keras.Sequential([
    # ...
    layers.Dropout(rate=0.3), # apply 30% dropout to the next layer
    layers.Dense(16),
    # ...
])

# %% [markdown]
# When adding dropout to a model we will usually want to increase the depth:

# %%
# Dropout model

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.Dropout(0.3),
    layers.Dense(512*2, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 512)               7168
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,057,793
# Trainable params: 1,057,793
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 1s 61ms/step - loss: 0.6418 - val_loss: 0.1468
# Epoch 2/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.1633 - val_loss: 0.1185
# Epoch 3/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1032 - val_loss: 0.0870
# Epoch 4/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0703 - val_loss: 0.0578
# Epoch 5/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0561 - val_loss: 0.0670
# Epoch 6/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0462 - val_loss: 0.0690
# Epoch 7/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0405 - val_loss: 0.0520
# Epoch 8/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0385 - val_loss: 0.0574
# Epoch 9/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0364 - val_loss: 0.0500
# Epoch 10/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0359 - val_loss: 0.0455
# Epoch 11/1000
# 15/15 [==============================] - 1s 49ms/step - loss: 0.0340 - val_loss: 0.0578
# Epoch 12/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0306 - val_loss: 0.0519
# Epoch 13/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0310 - val_loss: 0.0557
# Epoch 14/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0286 - val_loss: 0.0703
# Epoch 15/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0277 - val_loss: 0.0574
# Epoch 16/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0282 - val_loss: 0.0702
# Epoch 17/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0279 - val_loss: 0.0999
# Epoch 18/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0263 - val_loss: 0.0662
# Epoch 19/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0250 - val_loss: 0.0836
# Epoch 20/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0252 - val_loss: 0.0695
# Epoch 21/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0224 - val_loss: 0.0685
# Epoch 22/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0234 - val_loss: 0.0777
# Epoch 23/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0227 - val_loss: 0.0549
# Epoch 24/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0229 - val_loss: 0.0776
# Epoch 25/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0226 - val_loss: 0.0933
# Epoch 26/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.0221 - val_loss: 0.0669
# Epoch 27/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0228 - val_loss: 0.0859
# Epoch 28/1000
# 15/15 [==============================] - 1s 50ms/step - loss: 0.0217 - val_loss: 0.0640
# Epoch 29/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0203 - val_loss: 0.0783
# Epoch 30/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0195 - val_loss: 0.0742

# %% [markdown]
# ### 2.2.2 Batch Normalization
#
# [back to top](#top)
#
# Batch normalization ([batchnorm](https://arxiv.org/abs/1502.03167)) accomplishes a task very similar to sklearn's `StandardScaler`, and in fact, it can be added to the front of a neural network in place of sklearn's `StandardScaler` to scale and center the input data. But batchnorm is also used between layers, why would we want to rescale the output from one layer before feeding into the next? For the same reason we would want to scale and center our data in the first place: it levels the playing field for the following layer to find the important relationships. The optimizer algorithm, SGD, will shift weights in proportion to how large the activation is out of each neuron, and so large differences can lead to spurious behavior.
#
# In practice, batchnorm is often implemented to make the overall training time faster, rather than to improve the final loss (although in some cases it does do this as well). It is good to envoke batchnorm in particular, if you are dealing with neural networks that take a long time to train.
#
# Batchnorm can be added between layers, as well as between a layer and its activation function.

# %%
# BatchNorm model

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Dense(512*2, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mse',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

print(model.summary())

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=1000,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 512)               7168
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# dense_21 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,063,937
# Trainable params: 1,060,865
# Non-trainable params: 3,072
# _________________________________________________________________
# None
# Epoch 1/1000
# 15/15 [==============================] - 2s 63ms/step - loss: 3.2153 - val_loss: 2.6582
# Epoch 2/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.6181 - val_loss: 2.2152
# Epoch 3/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.2792 - val_loss: 1.8287
# Epoch 4/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.2140 - val_loss: 1.4207
# Epoch 5/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1480 - val_loss: 1.1948
# Epoch 6/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1297 - val_loss: 0.9166
# Epoch 7/1000
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1945 - val_loss: 0.6724
# Epoch 8/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1736 - val_loss: 0.6849
# Epoch 9/1000
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1509 - val_loss: 0.3573
# Epoch 10/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1788 - val_loss: 0.3543
# Epoch 11/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1196 - val_loss: 0.2317
# Epoch 12/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1163 - val_loss: 0.1333
# Epoch 13/1000
# 15/15 [==============================] - 1s 51ms/step - loss: 0.0663 - val_loss: 0.0579
# Epoch 14/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0401 - val_loss: 0.0557
# Epoch 15/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0285 - val_loss: 0.0455
# Epoch 16/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0335 - val_loss: 0.0467
# Epoch 17/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0298 - val_loss: 0.0398
# Epoch 18/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0281 - val_loss: 0.0443
# Epoch 19/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0311 - val_loss: 0.0319
# Epoch 20/1000
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0315 - val_loss: 0.0413
# Epoch 21/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0369 - val_loss: 0.0450
# Epoch 22/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0487 - val_loss: 0.0526
# Epoch 23/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0400 - val_loss: 0.0398
# Epoch 24/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0396 - val_loss: 0.0430
# Epoch 25/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0357 - val_loss: 0.0331
# Epoch 26/1000
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0435 - val_loss: 0.0514
# Epoch 27/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0410 - val_loss: 0.0394
# Epoch 28/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0505 - val_loss: 0.0400
# Epoch 29/1000
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0410 - val_loss: 0.0814
# Epoch 30/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0589 - val_loss: 0.0517
# Epoch 31/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0590 - val_loss: 0.0494
# Epoch 32/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0572 - val_loss: 0.0384
# Epoch 33/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0450 - val_loss: 0.0405
# Epoch 34/1000
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0337 - val_loss: 0.0330
# Epoch 35/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0333 - val_loss: 0.0488
# Epoch 36/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0334 - val_loss: 0.0539
# Epoch 37/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0390 - val_loss: 0.0930
# Epoch 38/1000
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0643 - val_loss: 0.0857
# Epoch 39/1000
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0619 - val_loss: 0.0473

# %%
# Show the learning curves
history_df = pd.DataFrame(history.history)
fig, ax = plt.subplots(1,1)
history_df.plot(ax=ax)
ax.set_ylim(0,.2)
# Out:
# (0.0, 0.2)

# %%
y_test_pred = np.exp(model.predict(X_test_std))
plt.plot(y_test_pred, np.exp(y_test_std), ls='', marker='o')

# %% [markdown]
# Model with BatchNorm and Dropout:

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Dropout and BatchNorm Model
model = keras.Sequential([
    layers.Dense(512, input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Activation('relu'), # separate activation
    layers.Dropout(0.3),
    layers.Dense(1024, activation='relu'), # built-in activation
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

# %%
print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 512)               7168
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_30 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,065,985
# Trainable params: 1,061,889
# Non-trainable params: 4,096
# _________________________________________________________________
# None

# %% [markdown]
# ### 2.2.3 Exercise: Try Batch Normalization and Dropout
#
# Create 3 models and train for 100 epochs with early stopping:
#
# 1. compile and train the model previously defined above
# 2. recreate the architecture but remove the batchnorm  layers
# 3. recreate the architecture but remove the dropout layers and one hidden, dense layer
#
# Compare the number of epochs required to converge, and the overall loss

# %%
# Dropout and BatchNorm Model
model = keras.Sequential([                      
    ### YOUR CODE HERE ###
    layers.Dense(512, input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Activation('relu'), # separate activation
    layers.Dropout(0.3),
    layers.Dense(1024, activation='relu'), # built-in activation
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mae',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=100,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 76ms/step - loss: 1.7324 - val_loss: 1.2784
# Epoch 2/100
# 15/15 [==============================] - 1s 65ms/step - loss: 1.3787 - val_loss: 0.8367
# Epoch 3/100
# 15/15 [==============================] - 1s 64ms/step - loss: 1.0480 - val_loss: 0.4903
# Epoch 4/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.8208 - val_loss: 0.2436
# Epoch 5/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.6621 - val_loss: 0.1582
# Epoch 6/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.5834 - val_loss: 0.1200
# Epoch 7/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.5215 - val_loss: 0.1186
# Epoch 8/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.4516 - val_loss: 0.1344
# Epoch 9/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.4120 - val_loss: 0.1411
# Epoch 10/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.3922 - val_loss: 0.1516
# Epoch 11/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.3672 - val_loss: 0.1285
# Epoch 12/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.3329 - val_loss: 0.1369
# Epoch 13/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.3173 - val_loss: 0.1120
# Epoch 14/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2922 - val_loss: 0.1048
# Epoch 15/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2767 - val_loss: 0.1078
# Epoch 16/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2748 - val_loss: 0.1230
# Epoch 17/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2627 - val_loss: 0.1152
# Epoch 18/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.2368 - val_loss: 0.1125
# Epoch 19/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.2306 - val_loss: 0.1285
# Epoch 20/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2264 - val_loss: 0.1126
# Epoch 21/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.2240 - val_loss: 0.1246
# Epoch 22/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.2107 - val_loss: 0.1372
# Epoch 23/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.2037 - val_loss: 0.1024
# Epoch 24/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.2022 - val_loss: 0.1243
# Epoch 25/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1981 - val_loss: 0.1067
# Epoch 26/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1934 - val_loss: 0.1063
# Epoch 27/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1934 - val_loss: 0.1003
# Epoch 28/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1844 - val_loss: 0.1005
# Epoch 29/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1780 - val_loss: 0.0974
# Epoch 30/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1734 - val_loss: 0.0994
# Epoch 31/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1820 - val_loss: 0.1207
# Epoch 32/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1782 - val_loss: 0.0970
# Epoch 33/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1689 - val_loss: 0.1059
# Epoch 34/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1672 - val_loss: 0.1027
# Epoch 35/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1668 - val_loss: 0.0937
# Epoch 36/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1648 - val_loss: 0.1009
# Epoch 37/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1618 - val_loss: 0.0934
# Epoch 38/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1624 - val_loss: 0.0952
# Epoch 39/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1586 - val_loss: 0.1028
# Epoch 40/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1655 - val_loss: 0.0999
# Epoch 41/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1585 - val_loss: 0.1187
# Epoch 42/100
# 15/15 [==============================] - 1s 62ms/step - loss: 0.1605 - val_loss: 0.0966
# Epoch 43/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1542 - val_loss: 0.0919
# Epoch 44/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1518 - val_loss: 0.0966
# Epoch 45/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1510 - val_loss: 0.0979
# Epoch 46/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1507 - val_loss: 0.0918
# Epoch 47/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1429 - val_loss: 0.0930
# Epoch 48/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1476 - val_loss: 0.0969
# Epoch 49/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1429 - val_loss: 0.0939
# Epoch 50/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1465 - val_loss: 0.0950
# Epoch 51/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1495 - val_loss: 0.1072
# Epoch 52/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1485 - val_loss: 0.0965
# Epoch 53/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1477 - val_loss: 0.1128
# Epoch 54/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1445 - val_loss: 0.1129
# Epoch 55/100
# 15/15 [==============================] - 1s 70ms/step - loss: 0.1438 - val_loss: 0.0942
# Epoch 56/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1365 - val_loss: 0.0982
# Epoch 57/100
# 15/15 [==============================] - 1s 65ms/step - loss: 0.1409 - val_loss: 0.0973
# Epoch 58/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1368 - val_loss: 0.0939
# Epoch 59/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1343 - val_loss: 0.0963
# Epoch 60/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1450 - val_loss: 0.0925
# Epoch 61/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.1388 - val_loss: 0.1042
# Epoch 62/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1380 - val_loss: 0.0956
# Epoch 63/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.1301 - val_loss: 0.0960

# %%
# Dropout and BatchNorm Model
model = keras.Sequential([                      
    ### YOUR CODE HERE ###
    layers.Dense(512, input_shape=[X_train_std.shape[1]]),
    # layers.BatchNormalization(),
    layers.Activation('relu'), # separate activation
    layers.Dropout(0.3),
    layers.Dense(1024, activation='relu'), # built-in activation
    layers.Dropout(0.3),
    # layers.BatchNormalization(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    # layers.BatchNormalization(),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mae',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=100,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 64ms/step - loss: 0.5856 - val_loss: 0.4674
# Epoch 2/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.3161 - val_loss: 0.2373
# Epoch 3/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.2414 - val_loss: 0.2476
# Epoch 4/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.2131 - val_loss: 0.2380
# Epoch 5/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1931 - val_loss: 0.1976
# Epoch 6/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1812 - val_loss: 0.1729
# Epoch 7/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1797 - val_loss: 0.2669
# Epoch 8/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1757 - val_loss: 0.2083
# Epoch 9/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1622 - val_loss: 0.2393
# Epoch 10/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1600 - val_loss: 0.2315
# Epoch 11/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1580 - val_loss: 0.1717
# Epoch 12/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1536 - val_loss: 0.1670
# Epoch 13/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1563 - val_loss: 0.1901
# Epoch 14/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1419 - val_loss: 0.1219
# Epoch 15/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1553 - val_loss: 0.2725
# Epoch 16/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1506 - val_loss: 0.2053
# Epoch 17/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1436 - val_loss: 0.1450
# Epoch 18/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1345 - val_loss: 0.1431
# Epoch 19/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1311 - val_loss: 0.2047
# Epoch 20/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1330 - val_loss: 0.1613
# Epoch 21/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1349 - val_loss: 0.1904
# Epoch 22/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1291 - val_loss: 0.1269
# Epoch 23/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1263 - val_loss: 0.1696
# Epoch 24/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1218 - val_loss: 0.1336
# Epoch 25/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1217 - val_loss: 0.1199
# Epoch 26/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1204 - val_loss: 0.1462
# Epoch 27/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1186 - val_loss: 0.1169
# Epoch 28/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1192 - val_loss: 0.1513
# Epoch 29/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1162 - val_loss: 0.1742
# Epoch 30/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1169 - val_loss: 0.1453
# Epoch 31/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1155 - val_loss: 0.1546
# Epoch 32/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1135 - val_loss: 0.1346
# Epoch 33/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1147 - val_loss: 0.1203
# Epoch 34/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1140 - val_loss: 0.1240
# Epoch 35/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1120 - val_loss: 0.1266
# Epoch 36/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1119 - val_loss: 0.1098
# Epoch 37/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1090 - val_loss: 0.0970
# Epoch 38/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1117 - val_loss: 0.1315
# Epoch 39/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1090 - val_loss: 0.0955
# Epoch 40/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1109 - val_loss: 0.0956
# Epoch 41/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1064 - val_loss: 0.1041
# Epoch 42/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1041 - val_loss: 0.0966
# Epoch 43/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1051 - val_loss: 0.1001
# Epoch 44/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1052 - val_loss: 0.0966
# Epoch 45/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1048 - val_loss: 0.1006
# Epoch 46/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1063 - val_loss: 0.1035
# Epoch 47/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1055 - val_loss: 0.0908
# Epoch 48/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1044 - val_loss: 0.1031
# Epoch 49/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1044 - val_loss: 0.0930
# Epoch 50/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1036 - val_loss: 0.0977
# Epoch 51/100
# 15/15 [==============================] - 1s 52ms/step - loss: 0.1048 - val_loss: 0.1020
# Epoch 52/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1045 - val_loss: 0.1041
# Epoch 53/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.1045 - val_loss: 0.0883
# Epoch 54/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1050 - val_loss: 0.1040
# Epoch 55/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1031 - val_loss: 0.0979
# Epoch 56/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1008 - val_loss: 0.0997
# Epoch 57/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1042 - val_loss: 0.0979
# Epoch 58/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1045 - val_loss: 0.0975
# Epoch 59/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.1008 - val_loss: 0.0936
# Epoch 60/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1006 - val_loss: 0.0975
# Epoch 61/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1000 - val_loss: 0.0931
# Epoch 62/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1034 - val_loss: 0.0898
# Epoch 63/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1012 - val_loss: 0.0954
# Epoch 64/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0996 - val_loss: 0.0946
# Epoch 65/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1013 - val_loss: 0.0951
# Epoch 66/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1009 - val_loss: 0.0944
# Epoch 67/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1020 - val_loss: 0.0955
# Epoch 68/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1002 - val_loss: 0.0952
# Epoch 69/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.1012 - val_loss: 0.0960
# Epoch 70/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0989 - val_loss: 0.1019
# Epoch 71/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.1005 - val_loss: 0.0904
# Epoch 72/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.1009 - val_loss: 0.0904
# Epoch 73/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.1005 - val_loss: 0.0934

# %%
# Dropout and BatchNorm Model
model = keras.Sequential([                      
    ### YOUR CODE HERE ###
    layers.Dense(512, input_shape=[X_train_std.shape[1]]),
    layers.BatchNormalization(),
    layers.Activation('relu'), # separate activation
    # layers.Dropout(0.3),
    layers.Dense(1024, activation='relu'), # built-in activation
    # layers.Dropout(0.3),
    layers.BatchNormalization(),
    # layers.Dense(512, activation='relu'),
    # layers.Dropout(0.3),
    # layers.BatchNormalization(),
    layers.Dense(1),
])

model.compile(
    optimizer='adam',
    loss='mae',
)

early_stopping = EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=256,
    epochs=100,
    verbose=1,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 42ms/step - loss: 1.9854 - val_loss: 1.1818
# Epoch 2/100
# 15/15 [==============================] - 0s 31ms/step - loss: 1.0592 - val_loss: 0.5808
# Epoch 3/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.5323 - val_loss: 0.1880
# Epoch 4/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.4227 - val_loss: 0.3112
# Epoch 5/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.3099 - val_loss: 0.1629
# Epoch 6/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.2706 - val_loss: 0.1635
# Epoch 7/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2263 - val_loss: 0.1478
# Epoch 8/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2347 - val_loss: 0.1988
# Epoch 9/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.2171 - val_loss: 0.1792
# Epoch 10/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2368 - val_loss: 0.1984
# Epoch 11/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2107 - val_loss: 0.1811
# Epoch 12/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.2685 - val_loss: 0.1713
# Epoch 13/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.2186 - val_loss: 0.2126
# Epoch 14/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.2071 - val_loss: 0.2059
# Epoch 15/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1786 - val_loss: 0.2080
# Epoch 16/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.1938 - val_loss: 0.1607
# Epoch 17/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1683 - val_loss: 0.1574
# Epoch 18/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1814 - val_loss: 0.2082
# Epoch 19/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1630 - val_loss: 0.1630
# Epoch 20/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1441 - val_loss: 0.1337
# Epoch 21/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1386 - val_loss: 0.1518
# Epoch 22/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1359 - val_loss: 0.1381
# Epoch 23/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.1620 - val_loss: 0.1381
# Epoch 24/100
# 15/15 [==============================] - 1s 33ms/step - loss: 0.1407 - val_loss: 0.1493
# Epoch 25/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.1531 - val_loss: 0.1500
# Epoch 26/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1437 - val_loss: 0.1454
# Epoch 27/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1288 - val_loss: 0.1497
# Epoch 28/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1502 - val_loss: 0.1220
# Epoch 29/100
# 15/15 [==============================] - 1s 33ms/step - loss: 0.1217 - val_loss: 0.1504
# Epoch 30/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1295 - val_loss: 0.1834
# Epoch 31/100
# 15/15 [==============================] - 0s 34ms/step - loss: 0.1523 - val_loss: 0.1318
# Epoch 32/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1177 - val_loss: 0.1303
# Epoch 33/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.1092 - val_loss: 0.1531
# Epoch 34/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.1089 - val_loss: 0.1495
# Epoch 35/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1035 - val_loss: 0.1404
# Epoch 36/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.1157 - val_loss: 0.1501
# Epoch 37/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1142 - val_loss: 0.1382
# Epoch 38/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.1075 - val_loss: 0.1407
# Epoch 39/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1116 - val_loss: 0.1194
# Epoch 40/100
# 15/15 [==============================] - 0s 34ms/step - loss: 0.1001 - val_loss: 0.1350
# Epoch 41/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1037 - val_loss: 0.1472
# Epoch 42/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1131 - val_loss: 0.1611
# Epoch 43/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1357 - val_loss: 0.1769
# Epoch 44/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.1319 - val_loss: 0.1573
# Epoch 45/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1182 - val_loss: 0.1249
# Epoch 46/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1190 - val_loss: 0.1730
# Epoch 47/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1161 - val_loss: 0.1197
# Epoch 48/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0992 - val_loss: 0.1283
# Epoch 49/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1115 - val_loss: 0.1344
# Epoch 50/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1083 - val_loss: 0.2600
# Epoch 51/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0934 - val_loss: 0.1377
# Epoch 52/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0881 - val_loss: 0.1259
# Epoch 53/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1052 - val_loss: 0.1418
# Epoch 54/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0996 - val_loss: 0.1091
# Epoch 55/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1024 - val_loss: 0.2092
# Epoch 56/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1022 - val_loss: 0.1292
# Epoch 57/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1025 - val_loss: 0.1289
# Epoch 58/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0988 - val_loss: 0.1363
# Epoch 59/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1149 - val_loss: 0.1269
# Epoch 60/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0972 - val_loss: 0.1226
# Epoch 61/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.1013 - val_loss: 0.1343
# Epoch 62/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0984 - val_loss: 0.1212
# Epoch 63/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1084 - val_loss: 0.1535
# Epoch 64/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1032 - val_loss: 0.1283
# Epoch 65/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0838 - val_loss: 0.1517
# Epoch 66/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.1029 - val_loss: 0.1185
# Epoch 67/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0919 - val_loss: 0.1503
# Epoch 68/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0929 - val_loss: 0.1258
# Epoch 69/100
# 15/15 [==============================] - 0s 34ms/step - loss: 0.0922 - val_loss: 0.1456
# Epoch 70/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0953 - val_loss: 0.1212
# Epoch 71/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0932 - val_loss: 0.1387
# Epoch 72/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.1011 - val_loss: 0.1083
# Epoch 73/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0917 - val_loss: 0.1164
# Epoch 74/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0839 - val_loss: 0.1093

# %% [markdown]
# ## 2.3 Binary Classification with Neural Networks
#
# When dealing with classification tasks, everything we've covered up till now with regression still applies. The main difference is the format of the last layer's outputs and the choice of loss function.

# %% [markdown]
# ### 2.3.1 Accuracy and Cross Entropy
#
# Formerly, we've encountered accuracy in classification tasks. It is the ratio of correct predictions over total predictions: `accuracy = number_corect / total` (and when classes were heavily imballanced we used a weighted accuracy).
#
# The problem with using accuracy as a loss function, is that it does not change smoothly (there are jumps in the numerator since it is just a count in correct predictions), which the SGD algorithm requires in order to work properly. We need another metric.
#
# <p align=center>
# <img src="https://i.imgur.com/DwVV9bR.png"></img>
#
# <small> the further a model is from predicting the correct class, the higher the loss. </small>
#
# Instead we use **_cross-entropy_**, we won't go into detail here, other than that it is a distance measure between two probabilities. What two probabilities are we measuring? We want the probability for predicting the correct class to be 1 (100%). cross-entropy will measure the distance the current probability of the model is from 1. The main takeaway here is that we will want to use cross-entropy for classification tasks.
#
# We set cross-entropy as our loss when we compile the model. In this case we have two classes so we use `binary_crossentropy`
#
# ```
# model.compile(
#     # optimizer...
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
# ```

# %% [markdown]
# ### 2.3.2 0 or 1: The Sigmoid Function
#
# Finally, we need to introduce a special activation function that will map our last layer outputs from 0 to 1, to feed into our loss function. The traditional function we use for this is the **_sigmoid function_**.
#
# <p align=center>
# <img src="https://i.imgur.com/FYbRvJo.png"></img>
#
# <small>The sigmoid function maps values on the interval [0, 1]</small>
#
# To get the final class prediction, we need a threshold probability, typically 0.5 where we will round up to the class label. Keras will set to 0.5 by default.
#
# We set the sigmoid activation function in the last layer:
#
# ```
# model = keras.Sequential([
#     # ... previous layers ...
#     layers.Dense(1, activation='sigmoid'),
# ])
# ```

# %% [markdown]
# ### 2.3.3 Classification Example

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('type')

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = y_train.map({'white': 0, 'red': 1}) # convert to int
y_val_std = y_val.map({'white': 0, 'red': 1}) # convert to int
y_test_std = y_test.map({'white': 0, 'red': 1}) # convert to int

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f90d74fe950>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f90d045f150>)])

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[X_train_std.shape[1]]),
    layers.Dense(4, activation='relu'),    
    layers.Dense(1, activation='sigmoid'),
])

print(model.summary())
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_46 (Dense)             (None, 4)                 52
# _________________________________________________________________
# dense_47 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 77
# Trainable params: 77
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model, 
                          show_layer_names=True, 
                          # show_dtype=True, 
                          show_shapes=True)

# %% [markdown]
# We set cross-entropy as our loss when we compile the model. In this case we have two classes so we use `binary_crossentropy`
#
# > Introducing `metrics`: we can track other forms of performance during training with the `metrics` parameter in `model.compile`. We will look at the results when we finish training.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'], # new metrics flag here
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1, 
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 22ms/step - loss: 0.6868 - binary_accuracy: 0.8180 - val_loss: 0.6724 - val_binary_accuracy: 0.8350
# Epoch 2/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6702 - binary_accuracy: 0.8292 - val_loss: 0.6565 - val_binary_accuracy: 0.8391
# Epoch 3/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6543 - binary_accuracy: 0.8415 - val_loss: 0.6408 - val_binary_accuracy: 0.8473
# Epoch 4/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6387 - binary_accuracy: 0.8536 - val_loss: 0.6253 - val_binary_accuracy: 0.8571
# Epoch 5/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6227 - binary_accuracy: 0.8615 - val_loss: 0.6101 - val_binary_accuracy: 0.8670
# Epoch 6/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6069 - binary_accuracy: 0.8695 - val_loss: 0.5948 - val_binary_accuracy: 0.8760
# Epoch 7/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5909 - binary_accuracy: 0.8779 - val_loss: 0.5790 - val_binary_accuracy: 0.8801
# Epoch 8/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5748 - binary_accuracy: 0.8859 - val_loss: 0.5631 - val_binary_accuracy: 0.8900
# Epoch 9/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5584 - binary_accuracy: 0.8952 - val_loss: 0.5470 - val_binary_accuracy: 0.9023
# Epoch 10/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5419 - binary_accuracy: 0.9012 - val_loss: 0.5306 - val_binary_accuracy: 0.9064
# Epoch 11/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5251 - binary_accuracy: 0.9089 - val_loss: 0.5140 - val_binary_accuracy: 0.9154
# Epoch 12/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5080 - binary_accuracy: 0.9154 - val_loss: 0.4971 - val_binary_accuracy: 0.9212
# Epoch 13/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4908 - binary_accuracy: 0.9256 - val_loss: 0.4801 - val_binary_accuracy: 0.9286
# Epoch 14/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4736 - binary_accuracy: 0.9373 - val_loss: 0.4633 - val_binary_accuracy: 0.9360
# Epoch 15/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4564 - binary_accuracy: 0.9455 - val_loss: 0.4466 - val_binary_accuracy: 0.9401
# Epoch 16/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4393 - binary_accuracy: 0.9510 - val_loss: 0.4300 - val_binary_accuracy: 0.9442
# Epoch 17/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4224 - binary_accuracy: 0.9562 - val_loss: 0.4135 - val_binary_accuracy: 0.9524
# Epoch 18/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4057 - binary_accuracy: 0.9614 - val_loss: 0.3973 - val_binary_accuracy: 0.9589
# Epoch 19/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3894 - binary_accuracy: 0.9628 - val_loss: 0.3815 - val_binary_accuracy: 0.9631
# Epoch 20/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3736 - binary_accuracy: 0.9652 - val_loss: 0.3660 - val_binary_accuracy: 0.9663
# Epoch 21/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3580 - binary_accuracy: 0.9688 - val_loss: 0.3509 - val_binary_accuracy: 0.9663
# Epoch 22/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3427 - binary_accuracy: 0.9699 - val_loss: 0.3361 - val_binary_accuracy: 0.9672
# Epoch 23/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3280 - binary_accuracy: 0.9724 - val_loss: 0.3218 - val_binary_accuracy: 0.9688
# Epoch 24/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3135 - binary_accuracy: 0.9743 - val_loss: 0.3080 - val_binary_accuracy: 0.9704
# Epoch 25/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2997 - binary_accuracy: 0.9756 - val_loss: 0.2945 - val_binary_accuracy: 0.9704
# Epoch 26/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2862 - binary_accuracy: 0.9759 - val_loss: 0.2817 - val_binary_accuracy: 0.9729
# Epoch 27/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2734 - binary_accuracy: 0.9767 - val_loss: 0.2694 - val_binary_accuracy: 0.9737
# Epoch 28/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2610 - binary_accuracy: 0.9781 - val_loss: 0.2578 - val_binary_accuracy: 0.9737
# Epoch 29/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2492 - binary_accuracy: 0.9789 - val_loss: 0.2467 - val_binary_accuracy: 0.9737
# Epoch 30/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.2379 - binary_accuracy: 0.9787 - val_loss: 0.2361 - val_binary_accuracy: 0.9737
# Epoch 31/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2273 - binary_accuracy: 0.9787 - val_loss: 0.2261 - val_binary_accuracy: 0.9737
# Epoch 32/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2171 - binary_accuracy: 0.9795 - val_loss: 0.2166 - val_binary_accuracy: 0.9745
# Epoch 33/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2074 - binary_accuracy: 0.9800 - val_loss: 0.2076 - val_binary_accuracy: 0.9745
# Epoch 34/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1985 - binary_accuracy: 0.9808 - val_loss: 0.1991 - val_binary_accuracy: 0.9745
# Epoch 35/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1899 - binary_accuracy: 0.9814 - val_loss: 0.1913 - val_binary_accuracy: 0.9762
# Epoch 36/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1820 - binary_accuracy: 0.9814 - val_loss: 0.1840 - val_binary_accuracy: 0.9787
# Epoch 37/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1746 - binary_accuracy: 0.9817 - val_loss: 0.1770 - val_binary_accuracy: 0.9787
# Epoch 38/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1675 - binary_accuracy: 0.9822 - val_loss: 0.1704 - val_binary_accuracy: 0.9795
# Epoch 39/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1610 - binary_accuracy: 0.9822 - val_loss: 0.1644 - val_binary_accuracy: 0.9795
# Epoch 40/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1548 - binary_accuracy: 0.9825 - val_loss: 0.1587 - val_binary_accuracy: 0.9795
# Epoch 41/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1491 - binary_accuracy: 0.9828 - val_loss: 0.1533 - val_binary_accuracy: 0.9803
# Epoch 42/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1437 - binary_accuracy: 0.9828 - val_loss: 0.1482 - val_binary_accuracy: 0.9819
# Epoch 43/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1386 - binary_accuracy: 0.9828 - val_loss: 0.1435 - val_binary_accuracy: 0.9803
# Epoch 44/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1339 - binary_accuracy: 0.9836 - val_loss: 0.1391 - val_binary_accuracy: 0.9811
# Epoch 45/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1295 - binary_accuracy: 0.9833 - val_loss: 0.1349 - val_binary_accuracy: 0.9819
# Epoch 46/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1253 - binary_accuracy: 0.9836 - val_loss: 0.1308 - val_binary_accuracy: 0.9819
# Epoch 47/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1214 - binary_accuracy: 0.9836 - val_loss: 0.1270 - val_binary_accuracy: 0.9819
# Epoch 48/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1176 - binary_accuracy: 0.9841 - val_loss: 0.1234 - val_binary_accuracy: 0.9828
# Epoch 49/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1141 - binary_accuracy: 0.9844 - val_loss: 0.1200 - val_binary_accuracy: 0.9828
# Epoch 50/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1108 - binary_accuracy: 0.9849 - val_loss: 0.1169 - val_binary_accuracy: 0.9828
# Epoch 51/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1076 - binary_accuracy: 0.9852 - val_loss: 0.1138 - val_binary_accuracy: 0.9828
# Epoch 52/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1047 - binary_accuracy: 0.9855 - val_loss: 0.1109 - val_binary_accuracy: 0.9828
# Epoch 53/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1018 - binary_accuracy: 0.9858 - val_loss: 0.1082 - val_binary_accuracy: 0.9836
# Epoch 54/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0992 - binary_accuracy: 0.9858 - val_loss: 0.1055 - val_binary_accuracy: 0.9836
# Epoch 55/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0966 - binary_accuracy: 0.9858 - val_loss: 0.1030 - val_binary_accuracy: 0.9844
# Epoch 56/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0942 - binary_accuracy: 0.9858 - val_loss: 0.1006 - val_binary_accuracy: 0.9860
# Epoch 57/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0919 - binary_accuracy: 0.9858 - val_loss: 0.0984 - val_binary_accuracy: 0.9860
# Epoch 58/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0897 - binary_accuracy: 0.9863 - val_loss: 0.0963 - val_binary_accuracy: 0.9860
# Epoch 59/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0876 - binary_accuracy: 0.9863 - val_loss: 0.0942 - val_binary_accuracy: 0.9869
# Epoch 60/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0856 - binary_accuracy: 0.9863 - val_loss: 0.0923 - val_binary_accuracy: 0.9869
# Epoch 61/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0838 - binary_accuracy: 0.9863 - val_loss: 0.0904 - val_binary_accuracy: 0.9877
# Epoch 62/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0820 - binary_accuracy: 0.9869 - val_loss: 0.0884 - val_binary_accuracy: 0.9877
# Epoch 63/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0802 - binary_accuracy: 0.9871 - val_loss: 0.0866 - val_binary_accuracy: 0.9885
# Epoch 64/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0786 - binary_accuracy: 0.9871 - val_loss: 0.0849 - val_binary_accuracy: 0.9893
# Epoch 65/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0770 - binary_accuracy: 0.9871 - val_loss: 0.0832 - val_binary_accuracy: 0.9893
# Epoch 66/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0754 - binary_accuracy: 0.9877 - val_loss: 0.0817 - val_binary_accuracy: 0.9893
# Epoch 67/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0739 - binary_accuracy: 0.9877 - val_loss: 0.0802 - val_binary_accuracy: 0.9893
# Epoch 68/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0725 - binary_accuracy: 0.9877 - val_loss: 0.0787 - val_binary_accuracy: 0.9901
# Epoch 69/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0711 - binary_accuracy: 0.9877 - val_loss: 0.0773 - val_binary_accuracy: 0.9901
# Epoch 70/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0698 - binary_accuracy: 0.9877 - val_loss: 0.0759 - val_binary_accuracy: 0.9901
# Epoch 71/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0685 - binary_accuracy: 0.9877 - val_loss: 0.0746 - val_binary_accuracy: 0.9901
# Epoch 72/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0673 - binary_accuracy: 0.9877 - val_loss: 0.0734 - val_binary_accuracy: 0.9901
# Epoch 73/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0662 - binary_accuracy: 0.9877 - val_loss: 0.0723 - val_binary_accuracy: 0.9901
# Epoch 74/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0651 - binary_accuracy: 0.9877 - val_loss: 0.0712 - val_binary_accuracy: 0.9901
# Epoch 75/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0640 - binary_accuracy: 0.9880 - val_loss: 0.0701 - val_binary_accuracy: 0.9901
# Epoch 76/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0630 - binary_accuracy: 0.9880 - val_loss: 0.0691 - val_binary_accuracy: 0.9901
# Epoch 77/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0621 - binary_accuracy: 0.9880 - val_loss: 0.0681 - val_binary_accuracy: 0.9901
# Epoch 78/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0611 - binary_accuracy: 0.9882 - val_loss: 0.0671 - val_binary_accuracy: 0.9901
# Epoch 79/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0602 - binary_accuracy: 0.9882 - val_loss: 0.0662 - val_binary_accuracy: 0.9901
# Epoch 80/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0593 - binary_accuracy: 0.9885 - val_loss: 0.0653 - val_binary_accuracy: 0.9901
# Epoch 81/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0585 - binary_accuracy: 0.9882 - val_loss: 0.0645 - val_binary_accuracy: 0.9901
# Epoch 82/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0576 - binary_accuracy: 0.9882 - val_loss: 0.0637 - val_binary_accuracy: 0.9901
# Epoch 83/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0568 - binary_accuracy: 0.9882 - val_loss: 0.0629 - val_binary_accuracy: 0.9901
# Epoch 84/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0560 - binary_accuracy: 0.9885 - val_loss: 0.0620 - val_binary_accuracy: 0.9901
# Epoch 85/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0553 - binary_accuracy: 0.9885 - val_loss: 0.0612 - val_binary_accuracy: 0.9901
# Epoch 86/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0545 - binary_accuracy: 0.9885 - val_loss: 0.0605 - val_binary_accuracy: 0.9901
# Epoch 87/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0538 - binary_accuracy: 0.9888 - val_loss: 0.0598 - val_binary_accuracy: 0.9901
# Epoch 88/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0532 - binary_accuracy: 0.9893 - val_loss: 0.0591 - val_binary_accuracy: 0.9901
# Epoch 89/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0525 - binary_accuracy: 0.9893 - val_loss: 0.0584 - val_binary_accuracy: 0.9901
# Epoch 90/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0518 - binary_accuracy: 0.9893 - val_loss: 0.0577 - val_binary_accuracy: 0.9901
# Epoch 91/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0512 - binary_accuracy: 0.9893 - val_loss: 0.0571 - val_binary_accuracy: 0.9901
# Epoch 92/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0506 - binary_accuracy: 0.9893 - val_loss: 0.0565 - val_binary_accuracy: 0.9901
# Epoch 93/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0500 - binary_accuracy: 0.9893 - val_loss: 0.0559 - val_binary_accuracy: 0.9901
# Epoch 94/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0494 - binary_accuracy: 0.9896 - val_loss: 0.0553 - val_binary_accuracy: 0.9901
# Epoch 95/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0488 - binary_accuracy: 0.9896 - val_loss: 0.0548 - val_binary_accuracy: 0.9901
# Epoch 96/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0483 - binary_accuracy: 0.9896 - val_loss: 0.0542 - val_binary_accuracy: 0.9901
# Epoch 97/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0477 - binary_accuracy: 0.9899 - val_loss: 0.0536 - val_binary_accuracy: 0.9901
# Epoch 98/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0472 - binary_accuracy: 0.9899 - val_loss: 0.0531 - val_binary_accuracy: 0.9901
# Epoch 99/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0467 - binary_accuracy: 0.9901 - val_loss: 0.0526 - val_binary_accuracy: 0.9901
# Epoch 100/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0462 - binary_accuracy: 0.9901 - val_loss: 0.0521 - val_binary_accuracy: 0.9901
# Epoch 101/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0457 - binary_accuracy: 0.9901 - val_loss: 0.0516 - val_binary_accuracy: 0.9901
# Epoch 102/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0453 - binary_accuracy: 0.9904 - val_loss: 0.0512 - val_binary_accuracy: 0.9901
# Epoch 103/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0448 - binary_accuracy: 0.9910 - val_loss: 0.0507 - val_binary_accuracy: 0.9901
# Epoch 104/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0444 - binary_accuracy: 0.9910 - val_loss: 0.0503 - val_binary_accuracy: 0.9901
# Epoch 105/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0440 - binary_accuracy: 0.9910 - val_loss: 0.0499 - val_binary_accuracy: 0.9901
# Epoch 106/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0436 - binary_accuracy: 0.9912 - val_loss: 0.0494 - val_binary_accuracy: 0.9901
# Epoch 107/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0432 - binary_accuracy: 0.9912 - val_loss: 0.0490 - val_binary_accuracy: 0.9901
# Epoch 108/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0428 - binary_accuracy: 0.9912 - val_loss: 0.0486 - val_binary_accuracy: 0.9901
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0424 - binary_accuracy: 0.9912 - val_loss: 0.0482 - val_binary_accuracy: 0.9901
# Epoch 110/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0420 - binary_accuracy: 0.9915 - val_loss: 0.0477 - val_binary_accuracy: 0.9901
# Epoch 111/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0417 - binary_accuracy: 0.9915 - val_loss: 0.0474 - val_binary_accuracy: 0.9901
# Epoch 112/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0413 - binary_accuracy: 0.9915 - val_loss: 0.0470 - val_binary_accuracy: 0.9901
# Epoch 113/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0410 - binary_accuracy: 0.9915 - val_loss: 0.0467 - val_binary_accuracy: 0.9901
# Epoch 114/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0406 - binary_accuracy: 0.9918 - val_loss: 0.0463 - val_binary_accuracy: 0.9901
# Epoch 115/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0403 - binary_accuracy: 0.9918 - val_loss: 0.0460 - val_binary_accuracy: 0.9901
# Epoch 116/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0400 - binary_accuracy: 0.9918 - val_loss: 0.0456 - val_binary_accuracy: 0.9901
# Epoch 117/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0396 - binary_accuracy: 0.9918 - val_loss: 0.0453 - val_binary_accuracy: 0.9901
# Epoch 118/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0393 - binary_accuracy: 0.9915 - val_loss: 0.0450 - val_binary_accuracy: 0.9901
# Epoch 119/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0390 - binary_accuracy: 0.9915 - val_loss: 0.0447 - val_binary_accuracy: 0.9901
# Epoch 120/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0387 - binary_accuracy: 0.9918 - val_loss: 0.0444 - val_binary_accuracy: 0.9901
# Epoch 121/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0384 - binary_accuracy: 0.9921 - val_loss: 0.0441 - val_binary_accuracy: 0.9910
# Epoch 122/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0381 - binary_accuracy: 0.9921 - val_loss: 0.0438 - val_binary_accuracy: 0.9910
# Epoch 123/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0378 - binary_accuracy: 0.9921 - val_loss: 0.0435 - val_binary_accuracy: 0.9910
# Epoch 124/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0375 - binary_accuracy: 0.9921 - val_loss: 0.0432 - val_binary_accuracy: 0.9910
# Epoch 125/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0372 - binary_accuracy: 0.9918 - val_loss: 0.0429 - val_binary_accuracy: 0.9910
# Epoch 126/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0370 - binary_accuracy: 0.9918 - val_loss: 0.0426 - val_binary_accuracy: 0.9910
# Epoch 127/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0367 - binary_accuracy: 0.9918 - val_loss: 0.0424 - val_binary_accuracy: 0.9910
# Epoch 128/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0364 - binary_accuracy: 0.9918 - val_loss: 0.0421 - val_binary_accuracy: 0.9910
# Epoch 129/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0362 - binary_accuracy: 0.9918 - val_loss: 0.0419 - val_binary_accuracy: 0.9910
# Epoch 130/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0359 - binary_accuracy: 0.9918 - val_loss: 0.0416 - val_binary_accuracy: 0.9910
# Epoch 131/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0357 - binary_accuracy: 0.9918 - val_loss: 0.0412 - val_binary_accuracy: 0.9910
# Epoch 132/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0355 - binary_accuracy: 0.9918 - val_loss: 0.0408 - val_binary_accuracy: 0.9910
# Epoch 133/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0352 - binary_accuracy: 0.9918 - val_loss: 0.0405 - val_binary_accuracy: 0.9910
# Epoch 134/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0350 - binary_accuracy: 0.9921 - val_loss: 0.0401 - val_binary_accuracy: 0.9910
# Epoch 135/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0347 - binary_accuracy: 0.9923 - val_loss: 0.0398 - val_binary_accuracy: 0.9910
# Epoch 136/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0345 - binary_accuracy: 0.9926 - val_loss: 0.0396 - val_binary_accuracy: 0.9910
# Epoch 137/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0343 - binary_accuracy: 0.9926 - val_loss: 0.0394 - val_binary_accuracy: 0.9910
# Epoch 138/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0341 - binary_accuracy: 0.9926 - val_loss: 0.0391 - val_binary_accuracy: 0.9910
# Epoch 139/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0338 - binary_accuracy: 0.9926 - val_loss: 0.0389 - val_binary_accuracy: 0.9910
# Epoch 140/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0336 - binary_accuracy: 0.9926 - val_loss: 0.0386 - val_binary_accuracy: 0.9910
# Epoch 141/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0334 - binary_accuracy: 0.9926 - val_loss: 0.0384 - val_binary_accuracy: 0.9910
# Epoch 142/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0332 - binary_accuracy: 0.9926 - val_loss: 0.0381 - val_binary_accuracy: 0.9910
# Epoch 143/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0330 - binary_accuracy: 0.9926 - val_loss: 0.0379 - val_binary_accuracy: 0.9910
# Epoch 144/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0328 - binary_accuracy: 0.9926 - val_loss: 0.0376 - val_binary_accuracy: 0.9910
# Epoch 145/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0326 - binary_accuracy: 0.9926 - val_loss: 0.0374 - val_binary_accuracy: 0.9910
# Epoch 146/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0324 - binary_accuracy: 0.9926 - val_loss: 0.0373 - val_binary_accuracy: 0.9910
# Epoch 147/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0323 - binary_accuracy: 0.9926 - val_loss: 0.0371 - val_binary_accuracy: 0.9910
# Epoch 148/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0321 - binary_accuracy: 0.9926 - val_loss: 0.0369 - val_binary_accuracy: 0.9918
# Epoch 149/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0319 - binary_accuracy: 0.9926 - val_loss: 0.0367 - val_binary_accuracy: 0.9918
# Epoch 150/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0318 - binary_accuracy: 0.9926 - val_loss: 0.0364 - val_binary_accuracy: 0.9918
# Epoch 151/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0316 - binary_accuracy: 0.9926 - val_loss: 0.0362 - val_binary_accuracy: 0.9918
# Epoch 152/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0314 - binary_accuracy: 0.9926 - val_loss: 0.0359 - val_binary_accuracy: 0.9918
# Epoch 153/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0313 - binary_accuracy: 0.9926 - val_loss: 0.0357 - val_binary_accuracy: 0.9926
# Epoch 154/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0311 - binary_accuracy: 0.9929 - val_loss: 0.0355 - val_binary_accuracy: 0.9926
# Epoch 155/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0309 - binary_accuracy: 0.9929 - val_loss: 0.0353 - val_binary_accuracy: 0.9926
# Epoch 156/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0308 - binary_accuracy: 0.9929 - val_loss: 0.0351 - val_binary_accuracy: 0.9926
# Epoch 157/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0306 - binary_accuracy: 0.9929 - val_loss: 0.0350 - val_binary_accuracy: 0.9926
# Epoch 158/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0305 - binary_accuracy: 0.9929 - val_loss: 0.0349 - val_binary_accuracy: 0.9926
# Epoch 159/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0303 - binary_accuracy: 0.9929 - val_loss: 0.0348 - val_binary_accuracy: 0.9926
# Epoch 160/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0302 - binary_accuracy: 0.9937 - val_loss: 0.0346 - val_binary_accuracy: 0.9926
# Epoch 161/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0301 - binary_accuracy: 0.9934 - val_loss: 0.0346 - val_binary_accuracy: 0.9934
# Epoch 162/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0300 - binary_accuracy: 0.9932 - val_loss: 0.0345 - val_binary_accuracy: 0.9934
# Epoch 163/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0298 - binary_accuracy: 0.9937 - val_loss: 0.0343 - val_binary_accuracy: 0.9934
# Epoch 164/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0297 - binary_accuracy: 0.9943 - val_loss: 0.0341 - val_binary_accuracy: 0.9934
# Epoch 165/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0295 - binary_accuracy: 0.9943 - val_loss: 0.0338 - val_binary_accuracy: 0.9934
# Epoch 166/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0294 - binary_accuracy: 0.9943 - val_loss: 0.0336 - val_binary_accuracy: 0.9934
# Epoch 167/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0292 - binary_accuracy: 0.9943 - val_loss: 0.0334 - val_binary_accuracy: 0.9934
# Epoch 168/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0291 - binary_accuracy: 0.9943 - val_loss: 0.0332 - val_binary_accuracy: 0.9934
# Epoch 169/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0290 - binary_accuracy: 0.9943 - val_loss: 0.0331 - val_binary_accuracy: 0.9934
# Epoch 170/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0289 - binary_accuracy: 0.9943 - val_loss: 0.0329 - val_binary_accuracy: 0.9934
# Epoch 171/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0287 - binary_accuracy: 0.9945 - val_loss: 0.0328 - val_binary_accuracy: 0.9943
# Epoch 172/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0286 - binary_accuracy: 0.9945 - val_loss: 0.0327 - val_binary_accuracy: 0.9943
# Epoch 173/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0285 - binary_accuracy: 0.9945 - val_loss: 0.0325 - val_binary_accuracy: 0.9943
# Epoch 174/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0284 - binary_accuracy: 0.9945 - val_loss: 0.0324 - val_binary_accuracy: 0.9951
# Epoch 175/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0282 - binary_accuracy: 0.9945 - val_loss: 0.0321 - val_binary_accuracy: 0.9951
# Epoch 176/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0281 - binary_accuracy: 0.9945 - val_loss: 0.0320 - val_binary_accuracy: 0.9951
# Epoch 177/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0280 - binary_accuracy: 0.9945 - val_loss: 0.0319 - val_binary_accuracy: 0.9951
# Epoch 178/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0278 - binary_accuracy: 0.9945 - val_loss: 0.0318 - val_binary_accuracy: 0.9951
# Epoch 179/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0277 - binary_accuracy: 0.9945 - val_loss: 0.0317 - val_binary_accuracy: 0.9951
# Epoch 180/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0276 - binary_accuracy: 0.9945 - val_loss: 0.0316 - val_binary_accuracy: 0.9951
# Epoch 181/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0275 - binary_accuracy: 0.9945 - val_loss: 0.0315 - val_binary_accuracy: 0.9951
# Epoch 182/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0274 - binary_accuracy: 0.9945 - val_loss: 0.0314 - val_binary_accuracy: 0.9951
# Epoch 183/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0273 - binary_accuracy: 0.9945 - val_loss: 0.0314 - val_binary_accuracy: 0.9951
# Epoch 184/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0272 - binary_accuracy: 0.9945 - val_loss: 0.0313 - val_binary_accuracy: 0.9951
# Epoch 185/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0270 - binary_accuracy: 0.9945 - val_loss: 0.0312 - val_binary_accuracy: 0.9951

# %%
history_df = pd.DataFrame(history.history)

history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_binary_accuracy'].max()))
# Out:
# Best Validation Loss: 0.0312
# Best Validation Accuracy: 0.9951

# %%
# predict test set
pred_probability = model.predict(X_test_std)

# convert to bool
predictions = pred_probability > 0.5

# precision / recall / f1-score 
print(classification_report(y_test_std,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1205
#            1       1.00      0.99      0.99       420
#
#     accuracy                           1.00      1625
#    macro avg       1.00      0.99      0.99      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
plt.figure(figsize=(10,6))
sns.heatmap(confusion_matrix(y_test_std,predictions),annot=True)

# %% [markdown]
# ## 2.3.4 Multi-Class Classification
#
# [back to top](#top)
#
# It is good practice, and often necessary to one-hot encode the target values for a multi-class problem. We will need to do that with our wine data here.

# %% [markdown]
# #### 2.3.4.1 Exercise: Multi-Class Classification
#
# 1) Define Model
#
# Define a model with both batch normalization and dropout layers.
#
# 2) Add Optimizer, Loss, and Metric
#
# 3) Train and Evaluate

# %%
from keras.utils import np_utils

# %%
wine = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
      "ds_for_engineers/main/data/wine_quality/winequalityN.csv")

# create X and y
X = wine.copy()
y = X.pop('quality')

# preprocess y for quality and/or type
encoder = LabelEncoder()
encoder.fit(y)
encoded_y = encoder.transform(y)
y = np_utils.to_categorical(encoded_y)

# split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train)

# the numerical values pipe
num_proc = make_pipeline(SimpleImputer(strategy='median'), StandardScaler())

# the categorical values pipe
cat_proc = make_pipeline(
    SimpleImputer(strategy='constant', fill_value='missing'),
    OneHotEncoder(handle_unknown='ignore'))

# parallelize the two pipes
preprocessor = make_column_transformer((num_proc,
                                make_column_selector(dtype_include=np.number)),
                                       (cat_proc,
                                make_column_selector(dtype_include=object)))

X_train_std = preprocessor.fit_transform(X_train) # fit_transform on train
X_test_std = preprocessor.transform(X_test) # transform test
X_val_std = preprocessor.transform(X_val)

y_train_std = y_train
y_val_std = y_val
y_test_std = y_test

preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2b41af1710>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7f2ace32c950>)])

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
  ### YOUR MODEL HERE ###
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

history = model.fit(
    X_train_std, y_train_std,
    validation_data=(X_val_std, y_val_std),
    batch_size=512,
    epochs=1000,
    callbacks=[early_stopping],
    verbose=1, # hide the output because we have so many epochs
)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 37ms/step - loss: 2.2256 - accuracy: 0.3276 - val_loss: 1.7893 - val_accuracy: 0.5287
# Epoch 2/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 1.8694 - accuracy: 0.4264 - val_loss: 1.6499 - val_accuracy: 0.5386
# Epoch 3/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7013 - accuracy: 0.4614 - val_loss: 1.5457 - val_accuracy: 0.5164
# Epoch 4/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.6154 - accuracy: 0.4620 - val_loss: 1.4295 - val_accuracy: 0.5025
# Epoch 5/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.5207 - accuracy: 0.5011 - val_loss: 1.3658 - val_accuracy: 0.4811
# Epoch 6/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.4501 - accuracy: 0.5025 - val_loss: 1.3375 - val_accuracy: 0.4762
# Epoch 7/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.3697 - accuracy: 0.5265 - val_loss: 1.2940 - val_accuracy: 0.4704
# Epoch 8/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.3400 - accuracy: 0.5216 - val_loss: 1.2521 - val_accuracy: 0.4696
# Epoch 9/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.2662 - accuracy: 0.5304 - val_loss: 1.2257 - val_accuracy: 0.4762
# Epoch 10/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.2336 - accuracy: 0.5380 - val_loss: 1.2070 - val_accuracy: 0.4795
# Epoch 11/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1775 - accuracy: 0.5512 - val_loss: 1.1872 - val_accuracy: 0.4778
# Epoch 12/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.1750 - accuracy: 0.5534 - val_loss: 1.1868 - val_accuracy: 0.4663
# Epoch 13/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1643 - accuracy: 0.5473 - val_loss: 1.1574 - val_accuracy: 0.4729
# Epoch 14/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1273 - accuracy: 0.5468 - val_loss: 1.1444 - val_accuracy: 0.5140
# Epoch 15/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1102 - accuracy: 0.5553 - val_loss: 1.1414 - val_accuracy: 0.4819
# Epoch 16/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0807 - accuracy: 0.5635 - val_loss: 1.1221 - val_accuracy: 0.5172
# Epoch 17/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0841 - accuracy: 0.5457 - val_loss: 1.1256 - val_accuracy: 0.5041
# Epoch 18/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0365 - accuracy: 0.5687 - val_loss: 1.1287 - val_accuracy: 0.5115
# Epoch 19/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0496 - accuracy: 0.5788 - val_loss: 1.1311 - val_accuracy: 0.5181
# Epoch 20/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0129 - accuracy: 0.5857 - val_loss: 1.1116 - val_accuracy: 0.5213
# Epoch 21/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0234 - accuracy: 0.5627 - val_loss: 1.1109 - val_accuracy: 0.5279
# Epoch 22/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0163 - accuracy: 0.5824 - val_loss: 1.1123 - val_accuracy: 0.5287
# Epoch 23/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0072 - accuracy: 0.5791 - val_loss: 1.1022 - val_accuracy: 0.5427
# Epoch 24/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0039 - accuracy: 0.5816 - val_loss: 1.0914 - val_accuracy: 0.5320
# Epoch 25/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 1.0092 - accuracy: 0.5769 - val_loss: 1.0935 - val_accuracy: 0.5255
# Epoch 26/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9788 - accuracy: 0.5928 - val_loss: 1.0825 - val_accuracy: 0.5378
# Epoch 27/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9824 - accuracy: 0.5870 - val_loss: 1.0750 - val_accuracy: 0.5599
# Epoch 28/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9697 - accuracy: 0.5903 - val_loss: 1.0845 - val_accuracy: 0.5468
# Epoch 29/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9719 - accuracy: 0.5900 - val_loss: 1.0768 - val_accuracy: 0.5460
# Epoch 30/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9670 - accuracy: 0.5944 - val_loss: 1.0731 - val_accuracy: 0.5402
# Epoch 31/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9682 - accuracy: 0.5914 - val_loss: 1.0707 - val_accuracy: 0.5443
# Epoch 32/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9465 - accuracy: 0.6043 - val_loss: 1.0691 - val_accuracy: 0.5476
# Epoch 33/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.9319 - accuracy: 0.6086 - val_loss: 1.0588 - val_accuracy: 0.5657
# Epoch 34/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9449 - accuracy: 0.5958 - val_loss: 1.0693 - val_accuracy: 0.5534
# Epoch 35/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9415 - accuracy: 0.6018 - val_loss: 1.0763 - val_accuracy: 0.5411
# Epoch 36/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9373 - accuracy: 0.6054 - val_loss: 1.0732 - val_accuracy: 0.5558
# Epoch 37/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9118 - accuracy: 0.6136 - val_loss: 1.0576 - val_accuracy: 0.5575
# Epoch 38/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9135 - accuracy: 0.6086 - val_loss: 1.0528 - val_accuracy: 0.5558
# Epoch 39/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8991 - accuracy: 0.6174 - val_loss: 1.0484 - val_accuracy: 0.5534
# Epoch 40/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9150 - accuracy: 0.6149 - val_loss: 1.0554 - val_accuracy: 0.5657
# Epoch 41/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9073 - accuracy: 0.6204 - val_loss: 1.0406 - val_accuracy: 0.5624
# Epoch 42/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9087 - accuracy: 0.6215 - val_loss: 1.0432 - val_accuracy: 0.5493
# Epoch 43/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9004 - accuracy: 0.6125 - val_loss: 1.0392 - val_accuracy: 0.5583
# Epoch 44/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9180 - accuracy: 0.6070 - val_loss: 1.0414 - val_accuracy: 0.5608
# Epoch 45/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8955 - accuracy: 0.6169 - val_loss: 1.0373 - val_accuracy: 0.5616
# Epoch 46/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8874 - accuracy: 0.6262 - val_loss: 1.0347 - val_accuracy: 0.5616
# Epoch 47/1000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8879 - accuracy: 0.6223 - val_loss: 1.0451 - val_accuracy: 0.5583
# Epoch 48/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8708 - accuracy: 0.6344 - val_loss: 1.0375 - val_accuracy: 0.5665
# Epoch 49/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8812 - accuracy: 0.6185 - val_loss: 1.0445 - val_accuracy: 0.5525
# Epoch 50/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8771 - accuracy: 0.6300 - val_loss: 1.0524 - val_accuracy: 0.5517
# Epoch 51/1000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8567 - accuracy: 0.6363 - val_loss: 1.0581 - val_accuracy: 0.5476
# Epoch 52/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8609 - accuracy: 0.6270 - val_loss: 1.0401 - val_accuracy: 0.5624
# Epoch 53/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8629 - accuracy: 0.6319 - val_loss: 1.0385 - val_accuracy: 0.5673
# Epoch 54/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8500 - accuracy: 0.6292 - val_loss: 1.0472 - val_accuracy: 0.5583
# Epoch 55/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8647 - accuracy: 0.6336 - val_loss: 1.0310 - val_accuracy: 0.5567
# Epoch 56/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8373 - accuracy: 0.6385 - val_loss: 1.0435 - val_accuracy: 0.5550
# Epoch 57/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8596 - accuracy: 0.6336 - val_loss: 1.0454 - val_accuracy: 0.5624
# Epoch 58/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8447 - accuracy: 0.6440 - val_loss: 1.0483 - val_accuracy: 0.5558
# Epoch 59/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8347 - accuracy: 0.6445 - val_loss: 1.0415 - val_accuracy: 0.5640
# Epoch 60/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8275 - accuracy: 0.6434 - val_loss: 1.0405 - val_accuracy: 0.5567
# Epoch 61/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8387 - accuracy: 0.6390 - val_loss: 1.0628 - val_accuracy: 0.5534
# Epoch 62/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8294 - accuracy: 0.6409 - val_loss: 1.0629 - val_accuracy: 0.5608
# Epoch 63/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8195 - accuracy: 0.6492 - val_loss: 1.0490 - val_accuracy: 0.5542
# Epoch 64/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8271 - accuracy: 0.6489 - val_loss: 1.0382 - val_accuracy: 0.5722
# Epoch 65/1000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8065 - accuracy: 0.6639 - val_loss: 1.0669 - val_accuracy: 0.5468

# %%
history_df = pd.DataFrame(history.history)

history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['accuracy', 'val_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(), 
              history_df['val_accuracy'].max()))
# Out:
# Best Validation Loss: 1.0310
# Best Validation Accuracy: 0.5722

# %%
# predict test set
pred_probability = model.predict(X_test_std)

# convert to bool
predictions = pred_probability > 0.5

# precision / recall / f1-score 
print(classification_report(y_test_std,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.11      0.18         9
#            1       0.00      0.00      0.00        54
#            2       0.62      0.63      0.63       516
#            3       0.56      0.62      0.59       717
#            4       0.62      0.16      0.26       286
#            5       0.00      0.00      0.00        41
#            6       0.00      0.00      0.00         2
#
#    micro avg       0.59      0.51      0.54      1625
#    macro avg       0.33      0.22      0.24      1625
# weighted avg       0.56      0.51      0.51      1625
#  samples avg       0.51      0.51      0.51      1625
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # References
#
# [Difference between a batch and an epoch](https://machinelearningmastery.com/difference-between-a-batch-and-an-epoch/)
#
# [Cross Entropy](https://machinelearningmastery.com/cross-entropy-for-machine-learning/)
