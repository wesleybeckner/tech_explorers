# %% [markdown]
# # Technology Explorers Course 3, Lab 2: Data Hunt I
#
# **Instructor**: Wesley Beckner
#
# **Contact**: wesleybeckner@gmail.com
#
# <br>
#
# ---
#
# <br>
#
# That's right you heard correctly. It's a data hunt.
#
# <br>
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wesleybeckner/"\
  "technology_explorers/main/assets/imdb_movies.csv")

# converting years to numbers for easy conditionals
df['year'] = pd.to_numeric(df['year'], errors='coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Q1 What american director has the highest average vote?

# %%
df.loc[df['country'] == 'USA'].groupby('director')['avg_vote'].mean().sort_values(ascending=False)
# Out:
# director
# Daniel Keith, Snorri Sturluson    9.3
# Anthony Bawn                      9.3
# Derek Ahonen                      9.2
# Raghav Peri                       9.1
# James Marlowe                     8.8
#                                  ...
# Waleed Bedour                     1.2
# Fred Ashman                       1.1
# Aeneas Middleton                  1.1
# Steven A. Sandt                   1.1
# Francis Hamada                    1.1
# Name: avg_vote, Length: 12463, dtype: float64

# %% [markdown]
# # Q2 What american director with more than 5 movies, has the highest average vote?

# %%
df.loc[df['country'] == 'USA'].groupby('director').filter(lambda x: x.shape[0] > 5).groupby('director')['avg_vote'].mean().sort_values(ascending=False)
# Out:
# director
# Quentin Tarantino     7.811111
# Charles Chaplin       7.764286
# David Fincher         7.625000
# Billy Wilder          7.580952
# Martin Scorsese       7.544444
#                         ...
# Barry Mahon           2.728571
# Dennis Devine         2.657143
# Bill Zebub            2.483333
# Mark Polonia          2.462500
# Christopher Forbes    2.000000
# Name: avg_vote, Length: 859, dtype: float64

# %% [markdown]
# # Q3 What director has the largest variance in rankings?

# %%
df.groupby('director')['avg_vote'].std().sort_values(ascending=False)
# Out:
# director
# Deniz Denizciler              4.030509
# Rudi Lagemann                 3.747666
# Emilio Ruiz Barrachina        3.676955
# Krishna Ghattamaneni          3.676955
# Milos Avramovic               3.606245
#                                 ...
# Ümit Degirmenci                    NaN
# Ümit Elçi                          NaN
# Ümit Köreken                       NaN
# Þorsteinn Gunnar Bjarnason         NaN
# Þórhildur Þorleifsdóttir           NaN
# Name: avg_vote, Length: 34733, dtype: float64

# %% [markdown]
# # Q4 What director with more than 10 movies has the largest variance in rankings?

# %%
df.groupby('director').filter(lambda x: x.shape[0] > 10).groupby('director')['avg_vote'].std().sort_values(ascending=False)
# Out:
# director
# Harry Baweja         1.869954
# Shaji Kailas         1.854502
# Zdenek Troska        1.775984
# Adam Rifkin          1.711251
# Ram Gopal Varma      1.687850
#                        ...
# Ford Beebe           0.224343
# Ray Nazarro          0.210311
# Jean Grémillon       0.196946
# Louis Feuillade      0.156428
# Tsutomu Shibayama    0.126121
# Name: avg_vote, Length: 1135, dtype: float64

# %% [markdown]
# # Q5 What american directors with more than 5 movies have the largest variance in rankings?

# %%
df.loc[df['country'] == 'USA'].groupby('director').filter(lambda x: x.shape[0] > 5).groupby('director')['avg_vote'].std().sort_values(ascending=False)
# Out:
# director
# Martin Brest          2.033716
# David Winters         1.926049
# Adam Rifkin           1.711251
# Gus Trikonis          1.661271
# Jerry Jameson         1.646107
#                         ...
# Edward Killy          0.155265
# Willis Goldbeck       0.139443
# Richard T. Heffron    0.136626
# Bill Plympton         0.136626
# Nate Watt             0.129099
# Name: avg_vote, Length: 859, dtype: float64

# %% [markdown]
# # Q6 Where does M. Night Shamalyan fall on this rank scale?
#
# (He's number 36/859)

# %%
dff = pd.DataFrame(df.loc[df['country'] == 'USA'].groupby('director').filter(lambda x: x.shape[0] > 5).groupby('director')['avg_vote'].std().sort_values(ascending=False)).reset_index()
dff.loc[dff['director'].str.contains("Shyamalan")]
# Out:
#               director  avg_vote
# 36  M. Night Shyamalan  1.258791

# %%
dff.iloc[:36]
# Out:
#                    director  avg_vote
# 0              Martin Brest  2.033716
# 1             David Winters  1.926049
# 2               Adam Rifkin  1.711251
# 3              Gus Trikonis  1.661271
# 4             Jerry Jameson  1.646107
# 5            David Giancola  1.607068
# 6         Peter Bogdanovich  1.564510
# 7             Ron Underwood  1.483721
# 8             Carl Colpaert  1.470261
# 9      Francis Ford Coppola  1.444077
# 10          James Merendino  1.438634
# 11         Lewis D. Collins  1.435367
# 12              Eric Weston  1.406769
# 13        Charles B. Pierce  1.406335
# 14    Franklin J. Schaffner  1.401700
# 15           Gorman Bechard  1.401428
# 16          Gene Fowler Jr.  1.400952
# 17  J. Christian Ingvordsen  1.384545
# 18             David Zucker  1.380459
# 19   Arthur Allan Seidelman  1.372224
# 20           Charlie Vaughn  1.364795
# 21            Curtis Hanson  1.361984
# 22               Craig Moss  1.357080
# 23          Victor Halperin  1.338282
# 24              Gerd Oswald  1.327696
# 25           Philip Kaufman  1.326147
# 26        Mario Van Peebles  1.317736
# 27            George Miller  1.315168
# 28               Lee Sholem  1.313652
# 29              Larry Brand  1.292672
# 30          Timothy A. Chey  1.291124
# 31              Kevin Lewis  1.289057
# 32              Griff Furst  1.287504
# 33        Michael Schroeder  1.275408
# 34                Tom Shell  1.265758
# 35           Mark L. Lester  1.262296

# %% [markdown]
# # Q7 How many movies were made each year in US from 2000-2020

# %%
df.loc[(df['country'] == 'USA') & (df['year'] >= 2000)].groupby('year')['title'].count()
# Out:
# year
# 2000.0    363
# 2001.0    386
# 2002.0    360
# 2003.0    339
# 2004.0    362
# 2005.0    453
# 2006.0    590
# 2007.0    574
# 2008.0    592
# 2009.0    656
# 2010.0    611
# 2011.0    652
# 2012.0    738
# 2013.0    820
# 2014.0    807
# 2015.0    800
# 2016.0    869
# 2017.0    905
# 2018.0    886
# 2019.0    700
# 2020.0    276
# Name: title, dtype: int64

# %% [markdown]
# # Q8 Visualize The Results of Q7!

# %%
fig, ax = plt.subplots(figsize=(10,5))
df.loc[(df['country'] == 'USA') & (df['year'] >= 2000)].groupby('year')['title'].count()\
  .plot(kind='bar', ax=ax)
ax.set_ylabel('Number of Movies')
# Out:
# Text(0, 0.5, 'Number of Movies')

# %% [markdown]
# # Q9 For single country movies, how many movies were made each year in each country from 2000-2020, only include countries that made more than 1000 movies in that timeframe

# %%
(df['country'].str.contains(',') == False)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 85850    False
# 85851     True
# 85852     True
# 85853     True
# 85854     True
# Name: country, Length: 85855, dtype: bool

# %%
df.loc[(df['country'].str.contains(',') == False) & (df['year'] >= 2000)].\
  groupby('country').filter(lambda x: x.shape[0] > 1000).\
  groupby(['country', 'year'])['title'].count()
# Out:
# country  year
# Canada   2000.0     39
#          2001.0     51
#          2002.0     49
#          2003.0     38
#          2004.0     52
#                   ...
# USA      2016.0    869
#          2017.0    905
#          2018.0    886
#          2019.0    700
#          2020.0    276
# Name: title, Length: 168, dtype: int64

# %%
df.loc[(df['country'].str.contains(',') == False) & (df['year'] >= 2000)].\
  groupby('country').filter(lambda x: x.shape[0] > 1000).\
  groupby(['country', 'year'])[['title']].count().reset_index().head()
# Out:
#   country    year  title
# 0  Canada  2000.0     39
# 1  Canada  2001.0     51
# 2  Canada  2002.0     49
# 3  Canada  2003.0     38
# 4  Canada  2004.0     52

# %% [markdown]
# # Q10 Visualize the results from Q9!

# %%
dff = df.loc[(df['country'].str.contains(',') == False) & (df['year'] >= 2000)].\
  groupby('country').filter(lambda x: x.shape[0] > 1000).\
  groupby(['country', 'year'])[['title']].count().reset_index()

# %%
fig, ax = plt.subplots(figsize=(10,7))
dff.pivot(columns='country', index='year', values='title').plot(ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10,7))
for country in dff.country.unique():
  dff.loc[dff.country == country].plot(x='year', y='title', ax=ax, label=country)

# %%
df.loc[(df['country'].str.contains(',') == False) & (df['year'] >= 2000)].\
  groupby('country').filter(lambda x: x.shape[0] > 1000).\
  groupby(['country', 'year'])['title'].count()
